# %%
# !pip uninstall xlrd
# Out:
# ^C

# %%
import pandas as pd
import os
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# !pip install pandas==1.1.1
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\msi\\anaconda3\\envs\\pandas1-new\\lib\\site-packages\\~andas\\_libs\\algos.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#      ---------------------------------------- 9.4/9.4 MB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.2
#     Uninstalling pandas-1.2.2:
#       Successfully uninstalled pandas-1.2.2

# %%
import pandas as pd
import os
import xlrd

# Define the directory path where the files are located
directory = 'dataset'

# Initialize an empty DataFrame to store the merged data
merged_data = pd.DataFrame()
data = pd.DataFrame()

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.xlsx'):  # Assuming the files are in CSV format
        file_path = os.path.join(directory, filename)
#         print( file_path )
        # Read the file into a DataFrame
#         data = pd.read_excel(file_path,encoding = 'latin1' ,header=None  )
        wb = xlrd.open_workbook(file_path )
        data = pd.read_excel(wb )

        # Delete the 40th row
        data.drop(38, inplace=True)
        data.drop(2, inplace=True)
        data.drop(1, inplace=True)
        data.drop(0, inplace=True)
        
        
        
        # Append the data to the merged_data DataFrame
        print(data.shape[1] , "  ", filename )

        merged_data = pd.concat([merged_data , pd.DataFrame(data)], ignore_index=True)
#         print(merged_data.head())


# Save the merged data to a new CSV file
merged_data.to_excel('merged_data.xlsx', index=False )
# merged_data.to_csv('merged_data.csv', index=False )

merged_data.head()
# Out:
# 14    Corona-Fallmeldungen-RLP-2021-08-01.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-02.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-03.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-04.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-05.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-06.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-07.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-08.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-09.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-10.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-11.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-12.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-13.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-14.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-15.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-16.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-17.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-18.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-19.xlsx
# 14    Corona-Fallmeldungen-RLP-2021-08-20.xlsx
# ...

# %%
merged_data.head(100)
# Out:
#                      0       1    2     3     4         5     6    7     8   \
# 0             Ahrweiler    4577    4   199    52      4423   102   65    50
# 1          Altenkirchen    4956    0   411   101      4833    22   11   8.5
# 2           Alzey-Worms    5130    1   304   123      4970    37   12   9.3
# 3          Bad Dürkheim    4499    1   305   150      4303    46   19  14.3
# 4         Bad Kreuznach    6121    0   160   142      5923    56   29  18.3
# 5   Bernkastel-Wittlich    3121    4   286    62      2997    62   38  33.8
# 6            Birkenfeld    3461    0   302    92      3298    71    9  11.1
# 7          Bitburg-Prüm    3430    0   163    31      3356    43   13  13.1
# 8           Cochem-Zell    1988    0   150    61      1908    19   13  21.2
# 9      Donnersbergkreis    2617    0   204    71      2518    28   15  19.9
# 10          Germersheim    5646    0   380   125      5450    71   39  30.2
# ...

# %%
# data = pd.read_excel("dataset\Corona-Fallmeldungen-RLP-2021-08-01.xlsx")
# data.head(50)
